# %%
# Import Dependencies
import pandas as pd
import numpy
import os

# %%
# Reference the file where the CSV is located
data_file = os.path.join("Resources","crime_incident_data2017.csv")

# Import the data into a Pandas DataFrame
data_frame = pd.read_csv(data_file)

# %%
# look for missing values
data_frame.count()
# Out:
# Address              37365
# Case Number          41032
# Crime Against        41032
# Neighborhood         39712
# Number of Records    41032
# Occur Date           41032
# Occur Month Year     41032
# Occur Time           41032
# Offense Category     41032
# Offense Count        41032
# Offense Type         41032
# Open Data Lat        36712
# Open Data Lon        36712
# Open Data X          36712
# Open Data Y          36712
# Report Date          41032
# Report Month Year    41032
# dtype: int64

# %%
# drop null rows
data_frame = data_frame.dropna(how='any')
data_frame.count()
# Out:
# Address              36146
# Case Number          36146
# Crime Against        36146
# Neighborhood         36146
# Number of Records    36146
# Occur Date           36146
# Occur Month Year     36146
# Occur Time           36146
# Offense Category     36146
# Offense Count        36146
# Offense Type         36146
# Open Data Lat        36146
# Open Data Lon        36146
# Open Data X          36146
# Open Data Y          36146
# Report Date          36146
# Report Month Year    36146
# dtype: int64

# %%
# verify counts
#see above

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
new_data_frame = data_frame["Offense Type"].unique()
pd.DataFrame(new_data_frame)
# Out:
#                                               0
# 0       False Pretenses/Swindle/Confidence Game
# 1                                Identity Theft
# 2                         Credit Card/ATM Fraud
# 3                                  Embezzlement
# 4                                   Shoplifting
# 5                             All Other Larceny
# 6                      Theft From Motor Vehicle
# 7                           Motor Vehicle Theft
# 8                                      Burglary
# 9   Theft of Motor Vehicle Parts or Accessories
# 10                       Counterfeiting/Forgery
# 11                                    Vandalism
# 12                          Theft From Building
# 13                                      Robbery
# 14                           Aggravated Assault
# 15   Theft From Coin-Operated Machine or Device
# 16                                 Intimidation
# 17                               Simple Assault
# 18                    Hacking/Computer Invasion
# ...

# %%
# Combine similar offenses
data_frame['Offense Type'].replace({})
# Out:
# 2            False Pretenses/Swindle/Confidence Game
# 5                                     Identity Theft
# 6            False Pretenses/Swindle/Confidence Game
# 7                                     Identity Theft
# 8                              Credit Card/ATM Fraud
# 9                                     Identity Theft
# 10                                    Identity Theft
# 11                                    Identity Theft
# 12                                      Embezzlement
# 15                                    Identity Theft
# 16                                       Shoplifting
# 17                                 All Other Larceny
# 18                                 All Other Larceny
# 19                                    Identity Theft
# 20                                    Identity Theft
# 21                          Theft From Motor Vehicle
# 22                          Theft From Motor Vehicle
# 23                                 All Other Larceny
# ...

# %%
# Create a new DataFrame that looks into a specific neighborhood
